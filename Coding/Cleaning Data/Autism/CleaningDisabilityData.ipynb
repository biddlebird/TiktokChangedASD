# %%
import pandas as pd

# %%
df = pd.read_csv('../../../Raw Data/Disability_and_Health_Data_System__DHDS_.csv')

print(df.columns)

print(df.head)
# Out:
# /var/folders/m9/nwvp3yqj5f76trygypnkypv80000gp/T/ipykernel_4947/1147201381.py:1: DtypeWarning: Columns (0,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../Raw Data/Disability_and_Health_Data_System__DHDS_.csv')
# Index(['Rowid', 'Year', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Category', 'Indicator', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Number',
#        'WeightedNumber', 'StratificationCategory1', 'Stratification1',
#        'StratificationCategory2', 'Stratification2', 'CategoryID',
#        'IndicatorID', 'Geolocation', 'LocationID', 'ResponseID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')
# ...

# %%
print("\nUnique in each column:")

for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nColumn: {column}")
    print(unique_values)
# Out:
# Unique in each column:
#
# Column: Rowid
# ['2019~11~JOB01~JOB~DISTYPE~SELFDIS~~' nan
#  '2019~82~JOB04~JOB~DISSTAT~NODIS~~' ... 13899.0 47595.0 70119.0]
#
# Column: Year
# [2019 2020 2016 2018 2017 2022 2021]
#
# Column: LocationAbbr
# ['DC' 'NJ' 'WV' 'RI' 'HHS8' 'HI' 'HHS7' 'HHS3' 'AR' 'WY' 'MS' 'FL' 'HHS4'
#  'ND' 'UT' 'IN' 'OH' 'MI' 'CA' 'NH' 'HHS6' 'HHS1' 'PR' 'NC' 'VA' 'KY'
#  'HHS10' 'VT' 'IA' 'TN' 'CT' 'AK' 'MT' 'ID' 'HHS9' 'DE' 'AL' 'PA' 'SC'
#  'NM' 'IL' 'KS' 'WI' 'OK' 'MO' 'HHS5' 'ME' 'NY' 'LA' 'AZ' 'MD' 'MA' 'OR'
#  'HHS2' 'NE' 'NV' 'GA' 'GU' 'TX' 'MN' 'SD' 'WA' 'CO' 'US' 'VI']
#
# Column: LocationDesc
# ['District of Columbia' 'New Jersey' 'West Virginia' 'Rhode Island'
#  'HHS Region 8' 'Hawaii' 'HHS Region 7' 'HHS Region 3' 'Arkansas'
#  'Wyoming' 'Mississippi' 'Florida' 'HHS Region 4' 'North Dakota' 'Utah'
#  'Indiana' 'Ohio' 'Michigan' 'California' 'New Hampshire' 'HHS Region 6'
#  'HHS Region 1' 'Puerto Rico' 'North Carolina' 'Virginia' 'Kentucky'
# ...
